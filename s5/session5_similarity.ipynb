# %% [markdown]
# ![bse_logo_textminingcourse](https://bse.eu/sites/default/files/bse_logo_small.png)

# %% [markdown]
# ## Introduction to Text Mining and Natural Language Processing
#
#
# ## Session 5: Similarity Measures and Tf-idf
#
# We will now start from the DTM that was generated as the 200 articles you saw previously. This is a labelled dataset where the data comes from a very small subset of a larger dataset that is unlabelled. The context is that we labelled a part of the data and then use this training to spot similar articles in the larger set. In order to prepare for that task, I have split a larger dataset into training and test set. We will first do everything on the training set and then get to the test set when we do supervised learning.
#
# The training_set.csv below is pre-processed but not vectorized. This notebook tries to show how different vectorizations and similarity methods shown in class affect what a query on an article returns.
#
# You will see also that comparing by the dot product is a risky idea - run the notebook entirely, go through and then discuss with your neighbor. In the end the tf-idf vectorization together with cosine similarity will yield the best fit to the article. Experiment a little with a different article.
#
# ### Context of the Data
#
# The text data in this corpus is dyadic text data. It is data that comes from an origin country and it talks about a destination country. There is also a time dimension which we ill ignore most of the time here.

# %%
# Imports
import os
import re
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, SnowballStemmer, PorterStemmer
from nltk.corpus import stopwords
import spacy
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer, TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from tqdm import tqdm

# Download required NLTK resources
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')

# Download and load spaCy model
from spacy.cli import download as spacy_download
spacy_download('en_core_web_sm')
sp = spacy.load('en_core_web_sm')

# Enable tqdm for pandas
tqdm.pandas()

# Initialize stemmers and lemmatizer
porter = SnowballStemmer('english')
lmtzr = WordNetLemmatizer()
STOP_WORDS = set(stopwords.words('english'))

# Set paths
path = '.'
spitout = '.'

# Define your file path and filename.
filename = 'training_set.csv'

# Load the data
corpus_data = pd.read_csv(os.path.join(path, filename), sep=',', encoding='utf-8')
corpus_data = corpus_data[pd.notna(corpus_data.text_preproc)].reset_index(drop=True)

print('The texts are about five different countries:')
corpus_data.dest_iso3c.value_counts()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/hannesfelixmuller/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hannesfelixmuller/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/hannesfelixmuller/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 5.5 MB/s  0:00:02m0:00:0100:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# The texts are about five different countries:
# dest_iso3c
# EGY    5492
# TUR    4369
# ISR    1632
# TUN     235
# MAR      24
# Name: count, dtype: int64

# %% [markdown]
# # Query Article
#
# We will try a very interesting query article. A short notice which does not have an exact match. You can try your own matching below.

# %%
#raw text
print(corpus_data.TXT_EN[5])
# Out:
# According to the Israeli ambassador, Rafael Eldad, 5,000 Brazilians face the risk of Palestinian attacks. Palestinian ambassador Ibrahim Alzeben says there are also Brazilians in the territories attacked by Israel.

# %%
#preprocessed text
print(corpus_data.text_preproc[5])
# Out:
# accord israeli ambassador Rafael Eldad 5,000 Brazilians face risk palestinian attack palestinian ambassador Ibrahim Alzeben say Brazilians territory attack Israel

# %% [markdown]
# ## Countvectorizer vs. Tf-idf

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the simple CountVectorizer
cv_simple = CountVectorizer(ngram_range=(1,2), lowercase=False, min_df=0.01, max_df=0.6)

# Fit the vectorizer to the preprocessed text data
X_simple = cv_simple.fit_transform(corpus_data.text_preproc)

# Get the vocabulary (terms)
terms_simple = cv_simple.get_feature_names_out()

# Calculate term frequencies (total counts across all documents)
term_frequencies_simple = X_simple.toarray().sum(axis=0)

# Create a DataFrame for easier handling
import pandas as pd

df_terms_simple = pd.DataFrame({
    'term': terms_simple,
    'frequency': term_frequencies_simple
})

# Sort the DataFrame by frequency in descending order
df_terms_simple = df_terms_simple.sort_values(by='frequency', ascending=False).reset_index(drop=True)

# Display the top 10 terms as a sanity check
print(df_terms_simple.head(10))
# Out:
#        term  frequency
# 0     Egypt      22526
# 1    Turkey      19234
# 2       say      17297
# 3    Israel      11037
# 4  egyptian      10172
# 5   turkish       9503
# 6   country       7819
# 7   israeli       7233
# 8      kill       6893
# 9      Gaza       6568

# %%
cv_tfidf = TfidfVectorizer(ngram_range = (1,2), norm=None, sublinear_tf=True, lowercase=False, min_df=0.01, max_df=0.6)
cv_tfidf.fit(corpus_data.text_preproc)
# Fit the vectorizer to the preprocessed text data
X_tfidf = cv_tfidf.fit_transform(corpus_data.text_preproc)

# Get the vocabulary (terms)
terms_tfidf = cv_tfidf.get_feature_names_out()

# Calculate term frequencies (total counts across all documents)
term_frequencies_tfidf = X_tfidf.toarray().sum(axis=0)

# Create a DataFrame for easier handling
import pandas as pd

df_terms_tfidf = pd.DataFrame({
    'term': terms_tfidf,
    'frequency': term_frequencies_tfidf
})

# Sort the DataFrame by frequency in descending order
df_terms_tfidf = df_terms_tfidf.sort_values(by='frequency', ascending=False).reset_index(drop=True)

# Display the top 10 terms as a sanity check
print(df_terms_tfidf.head(10))
# Out:
#        term     frequency
# 0     Egypt  20146.234079
# 1    Turkey  18523.180512
# 2       say  17841.644007
# 3  egyptian  13786.580955
# 4    Israel  13489.171161
# 5   turkish  13330.544776
# 6   country  12111.161462
# 7      kill  11800.099328
# 8    attack  11030.829944
# 9   israeli  10879.267536

# %%
print(corpus_data.text_preproc[40])
# Out:
# U.S. diplomat urge Egyptians hold dialogue visit U.S. Deputy Secretary State William Burns Monday urge political faction Egypt engage dialogue end violence official news agency MENA report ask U.S. President Barack Obama Secretary State John Kerry visit Egypt clarify U.S. stance Burns say brief news conference U.S. embassy Cairo message clear United States continue commit democratic success prosperity Egypt say Burns high level diplomat visit Egypt July 3 islamist orient President Mohamed Morsi oust armed force massive nationwide protest call removal Burns meet member egyptian transitional government armed force representative different political party NGOs activist religious figure businessman Al Nour second important islamic party Egypt say decide express rejection U.S. intervention Egypt domestic affair Tamarud founder Mahmoud Badr say U.S. administration need acknowledge new system apologize support Muslim Brotherhood party terrorism Burns say Egyptians determine future come U.S. solution lecture United States seek impose certain model Egypt support certain main principle say early Monday Egyptian Defense Minister Abdel Fatah al Sisi meet Burns hail army response people state run Al Ahram Online report swift reaction Morsi ouster Obama say deeply concern military later order defense department review U.S. foreign assistance program Egypt 1.5 billion U.S. dollar aid year Obama openly label military procedure coup call Egypt army transfer power civilian government soon possible urge avoid arbitrary arrest Morsi supporter statement Friday Washington call egyptian military interim leader release Morsi reportedly house arrest

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

DOC_INDICES = [5]

###############################################################################
# 1) DOT PRODUCT
###############################################################################
def most_similar_by_dot_product(X, doc_index):
    # Cast the result to float to avoid the "cannot convert float infinity to integer" error
    dot_values = X[doc_index].dot(X.T).toarray().ravel().astype(float)
    dot_values[doc_index] = -np.inf
    return np.argmax(dot_values).item()

def find_closest_docs_dot_product(X, doc_indices):
    return {
        i: most_similar_by_dot_product(X, i)
        for i in doc_indices
    }

###############################################################################
# 2) COSINE SIMILARITY
###############################################################################
def most_similar_by_cosine(X, doc_index):
    cos_values = cosine_similarity(X[doc_index], X).ravel()
    cos_values[doc_index] = -np.inf
    return np.argmax(cos_values).item()

def find_closest_docs_cosine(X, doc_indices):
    return {
        i: most_similar_by_cosine(X, i)
        for i in doc_indices
    }



###############################################################################
# -- Main routine: Evaluate all 6 queries
###############################################################################
dot_tfidf_results = find_closest_docs_dot_product(X_tfidf, DOC_INDICES)
dot_simple_results = find_closest_docs_dot_product(X_simple, DOC_INDICES)

cos_tfidf_results = find_closest_docs_cosine(X_tfidf, DOC_INDICES)
cos_simple_results = find_closest_docs_cosine(X_simple, DOC_INDICES)

print("Nearest by DOT PRODUCT (TF-IDF):", dot_tfidf_results)
print("Nearest by DOT PRODUCT (Count) :", dot_simple_results)
print("Nearest by COSINE (TF-IDF)      :", cos_tfidf_results)
print("Nearest by COSINE (Count)       :", cos_simple_results)
# Out:
# Nearest by DOT PRODUCT (TF-IDF): {5: 6834}
# Nearest by DOT PRODUCT (Count) : {5: 3412}
# Nearest by COSINE (TF-IDF)      : {5: 6754}
# Nearest by COSINE (Count)       : {5: 6754}

# %%
import textwrap

def print_article(title, text, width=100):
    print(title)
    print("-" * len(title))
    print(textwrap.fill(str(text), width=width))
    print()

print_article("Query article", corpus_data.TXT_EN[5])

print_article("DOT PRODUCT (TF-IDF)", corpus_data.TXT_EN[6834])
print_article("DOT PRODUCT (Count)", corpus_data.TXT_EN[3412])
print_article("COSINE (TF-IDF)", corpus_data.TXT_EN[6754])
print_article("COSINE (Count)", corpus_data.TXT_EN[6754])
# Out:
# Query article
# -------------
# According to the Israeli ambassador, Rafael Eldad, 5,000 Brazilians face the risk of Palestinian
# attacks. Palestinian ambassador Ibrahim Alzeben says there are also Brazilians in the territories
# attacked by Israel.
#
# DOT PRODUCT (TF-IDF)
# --------------------
# Thousands live in areas that can be hit, according to Israeli diplomats and ANP in BrasÃ­lia
# BRASÃLIA and ASHKELON, Israel Israel's ambassador to Brazil, Rafael Eldad, said yesterday that
# about half of the 10,000 Brazilians living in his country may fall victim to attacks by residents in
# the area and areas near Tel Aviv, against which Palestinians fired rockets. The Brazilian National
# Authority (ANP) ambassador to Brazil, Ibrahim Alzeben, says that there are also Brazilians in the
# territories attacked by Israel. - There are also Brazilians in the Gaza Strip and the West Bank. The
# solution is the end of the conflict, of the bombardment. The missiles are hitting our people. The
# end of the attacks of Israel, which occupies our territory, is also for the good of the Brazilians,
# the Americans and many others who live there. We share our territories with other peoples and now,
# unfortunately, we also share the conflict. It is not beneficial to anyone - he said. According to
# Eldad, the attack on Tel Aviv is deliberate and targets the civilian population. He argues that
# Israeli bombings in Gaza target terrorists rather than civilians: - The main difference is that
# Israel is defending itself, trying to destroy those who send missiles and rockets. They attack from
# within houses, mosques and schools. But on the other side, in a deliberate way, they seek to kill
# civilians. That's the difference. It's a massive attack. No government would tolerate this. As if it
# were in Brazil, attacks on Rio, Salvador.JÃ¡ Alzeben affirms that the attacks on Tel Aviv and
# Jerusalem are a response to the actions of Israel. The 47-year-old woman from Lilian Cohen, 47 years
# old - nine of them in Israel - knows that , every time the siren sounds, it will find the neighbors
# on the steps of the building where it lives, in Beer Sheva, the "capital of the south", 40km from
# Gaza. She does not have a reinforced room. With the family - the carioca Donald, 53, and the
# children Gabriel, 20, and Ionah, 16 - have a minute to run to the safest place possible, even in the
# middle of the night.
#
# DOT PRODUCT (Count)
# -------------------
# Re: True friends of Israel must criticize its policies, Opinion Aug. 9      Mulcair's column doesn't
# quite cut it. Why should the Canadian people, either through their taxes or through money they
# pledge to Canadian charities and nonprofit organizations have to rebuild Gaza? Shouldn't Israel do
# that. It killed 1,900 people, including 450 children, injured nearly 10,000 seriously, and made more
# than 400,000 Gazans homeless by destroying their homes, or making them refugees (again) in their own
# country.      Israel has simply walked away from the destruction of another country and we are
# expected to rebuild it!      Harper and Baird continue to portray the Palestinian child victims of
# Israel collective punishment as just collateral-damage victims Hamas. They fear admitting them for
# treatment in Canadian hospitals because it puts a face on these victims. They want to keep them
# thousands of miles away from the eyes of compassionate Canadians.      My wife Joyce and I served
# with the Ecumenical Accompaniment Program in Palestine and Israel (EAPPI) with the World Council of
# Churches from November 2013 to February 2014. I served in Bethlehem and East Jerusalem, while Joyce
# was in East Jerusalem throughout.      We were part of a team of some 35 people situated throughout
# the West Bank monitoring human rights situations and providing protective presence to people living
# under the Israeli occupation, which has continued for more than four decades. Having returned to
# Canada, we now spend a significant amount of our time making public presentations on our experiences
# and the background that informs what we witnessed.      EAPPI, which supports non-violent resistance
# to end the occupation, operates year-round in Palestine, providing eyes and ears on the ground for
# the World Council of Churches and indirectly for the United Nations. We also briefed the Canadian
# ambassadorial staff in Tel Aviv at one point during our stay.      We served at checkpoints,
# watching how Palestinians were treated, visited villages, neighbourhoods and homes, and stood
# witness at Palestinian elementary and secondary schools where Israeli soldiers regularly patroled.
# We listened not only to Palestinian witnesses, but also to dissident Israeli activists who are
# appalled by what their government is doing.      These included Women in Black and Breaking the
# Silence, among others, as well as Christian resistance groups like Sabeel and various churches. We
# were especially fortunate to meet by chance, activist Miko Peled, son of Israeli war hero-turned-
# peace-activist Matti Peled. Miko does not mince words: he calls the Israeli Defense Force (IDF) a
# "terrorist organization," and he has deliberately reached out to Palestinian individuals and groups
# to build bridges of understanding and respect.      It is especially important, in light of the
# horrific bombardment of Gaza, to hear the dissenting voices concerning Gaza and the occupation of
# Palestine. Our current federal government, by unthinkingly supporting the state of Israel, is also
# supporting theft of Palestinian land and resources, Israeli state-supported settlement expansion,
# the brutal military occupation of Palestine and the strangulation of Gaza.      Yet tonight as we
# bare witness to the fury of the Israeli attack on the citizens of Gaza, there is no cry for a
# humanitarian intervention. Why is that? If you prick a Palestinian does he not bleed?      True
# friends of Israel must criticize its policies, Opinion Aug. 9      Like Anthony Cantor, fair minded
# Jews all over the world continue to criticize and condemn Israel's wartime atrocities. What is so
# disturbing is the unbalanced and partisan position adopted by Benjamin Netanyahu's choir boys in
# Canada; Messers. Stephen Harper, Justin Trudeau and Tom Mulcair. It's deplorable.      Such a stance
# by these leaders will not advance the cause of two-nation solution. Every Palestinian child that is
# killed by the Israeli war machine, every school it bombs, every house it demolishes for no
# discernable reason will backfire into the face of innocent Jewish people.      Actions in Gaza by
# the Israeli leadership and army, and their minority of powerful supporters around the world, have
# unquestionable heart breaking short-term effects. But if history repeats itself, the long-term
# beneficiaries will be the Palestinians.      The Star should also publish an article on why so many
# Jews, like myself, support and deeply appreciate Prime Minister Stephen Harper for his steadfast
# support of Israel. Polls in Israel and the U.S. show the vast majority of Jews support Israel's
# conduct of its war against Hamas, another of the various brutal Islamist groups ravaging the Middle
# East, Afghanistan and Pakistan.      It is certainly not the FLQ. Had any democracy, including
# Canada and the U.S., been subjected, like Israel, to scores of suicide bombings of civilians and
# thousands of rockets and missiles fired at its cities, it would have taken no less action against
# such an enemy.      It is sadly true that Canada's political establishment, by remaining uncritical
# of Israel, has contributed to the continuation of a broken peace process in Gaza. The deafening
# silence of our key federal leaders Harper, Trudeau and Mulcair is tantamount to an abrogation of
# their duty to help in brokering peace. Credible world leaders cannot, and must not, look the other
# way as Netanyahu systematically undermines the possibility of a Palestinian state.      It is a
# credit to those Jewish Canadians who voiced public criticism of Israeli policies. Many have been
# outspoken about the Israeli overreaction and wanton destruction of Palestinian lives, property and
# their very livelihood. Israel's former president Shimon Peres has praised the president of the
# Palestinian Authority, Mahmoud Abbas, as a worthy partner for peace. Israeli Justice Minister Tzipi
# Livni even warned that failure to realize the goal of two states for two peoples could usher in "a
# dark future for Israel."      Palestinian sympathizers should also strive to push for an end to
# firing rockets and stop building tunnels that have provoked the Israelis. These measures have
# actually proven to be highly ineffective, given the Israeli Iron Dome defence and infinitely greater
# fire power, and have even been counterproductive - by enhancing Netanyahu's support among the
# Israeli population who are in favour of peace. The needs and desires of both Israelis and
# Palestinians to live in peace has to be guaranteed.      Let us hope that Canada's leaders will take
# the high road in opposing the brutal oppression of Palestinians and also in persuading our Israeli
# friends that denying human rights to a subject population poses a real threat to Israel's future as
# a democracy.      My heartfelt thanks to Anthony Cantor for a forceful expression of support for
# Israel that calls for policies with a realistic path to a two-state solution. As he says, getting
# there requires a negotiated end to the occupation. But that is not the position that Netanyahu
# espouses. Pointing that out takes courage that the Harper government does not have.      Mr.
# Cantor's editorial is a tired regurgitation of many on the left's views of the Harper government's
# position on Israel.      First, he implies that the Harper government and those that support its
# position do not want a peaceful solution between Israel and the Gaza. That is of course nonsense,
# but a lasting peace must be one where Israel's right to exist and security are a condition
# precedent.      He once again bring's up Canada's supposed lost role as an "honest broker." What is
# dishonest about supporting right versus wrong, which is the basis of the Harper government's policy
# on Israel?      The Middle East basics with respect to Israel will change only when Hamas and its
# supporters say "Enough warfare and killing - we accept there can be a Jewish state, we will not
# longer attempt its destruction, nor advocate an international Holocaust against Jews." He may then
# comment on the reaction of Canadian politicians to the prospect of peace and cooperation between
# Israelis and Arabs.      The voices in the North American Jewish community mentioned by Cantor that
# are both pro-Israel and pro-peace are entitled to be critical of Israeli policies, but they have
# never advocated destruction of the Jewish state. The basic underlying truths as seen by Israelis is:
# live and let live. By Hamas: No Israel, no Jews.      Over the last few weeks the Star has offered
# its readers a number of forcefully written columns by various authors dealing with the seemingly
# unsolvable "Palestinian Question" in the Middle East. The authors offered various points of view and
# presented interested readers with all kinds of critical information that might help them to try and
# understand what the Israeli/Palestinian conflict was all about.      Surely the majority of Israeli
# and Palestinian people do want an end to this seemingly interminable conflict.      Anthony Cantor's
# opinion piece on Israel betrays a youthful enthusiasm and naivete that is not particularly
# informative or helpful. While [correctly] calling upon the Canadian government to be vocal in
# criticizing Israeli Prime Minister Netanyahu for obstructing the possibility of a two-state
# solution, Mr. Cantor conveniently ignores the reality that the Palestinian leadership also is
# unwilling to make the necessary concessions to bring about such a settlement. Moderates on both
# sides are frustrated with their respective leaderships.      As regards Gaza, Mr. Cantor - while
# condemning Hamas - criticizes Israel's "assault" without explaining what would have been an
# acceptable Israeli response to Hamas' rockets. Israel's choice of targets is indeed open to question
# but a vigorous Israeli military action was surely more than justified.      GRAPHIC: Medics assist a
# wounded Palestinian girl upon her arrival at the hospital in Rafah, in southern Gaza on Aug. 2
# following an Israeli military strike.
#
# COSINE (TF-IDF)
# ---------------
# Danger: See images of Brazilians who are under threat of Palestinian attacks on Israel
#
# COSINE (Count)
# --------------
# Danger: See images of Brazilians who are under threat of Palestinian attacks on Israel

# %% [markdown]
# Very clearly cosine similarity "wins". Why is this? Discuss with your neighbor.
